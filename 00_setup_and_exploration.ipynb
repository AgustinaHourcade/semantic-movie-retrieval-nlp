# %% [markdown]
# # Setup y Exploración de Datos (EDA)

# %% [markdown]
# ## 1. Sección de Setup
#
# Instalación de las dependencias requeridas para el proyecto.

# %%
# Instalar dependencias desde requirements.txt y librerías de visualización
# %pip install -r requirements.txt
# %pip install matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: jupyter in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: transformers in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (5.9.0)
# Requirement already satisfied: sentence-transformers in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (5.5.1)
# Requirement already satisfied: torch in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (2.11.0)
# Requirement already satisfied: rank_bm25 in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: scikit-learn in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: nltk in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (3.9.1)
# Requirement already satisfied: faiss-cpu in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (1.14.2)
# Requirement already satisfied: streamlit in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (1.45.1)
# Requirement already satisfied: python-dotenv in c:\users\agustina\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\agustina\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\agustina\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\agustina\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\agustina\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: notebook in c:\users\agustina\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (7.3.2)
# Requirement already satisfied: jupyter-console in c:\users\agustina\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\agustina\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\agustina\appdata\roaming\python\python313\site-packages (from jupyter->-r requirements.txt (line 2)) (6.30.1)
# Requirement already satisfied: ipywidgets in c:\users\agustina\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\agustina\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (4.3.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (1.16.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (0.22.2)
# Requirement already satisfied: typer in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\agustina\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\agustina\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\agustina\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\agustina\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\agustina\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\agustina\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: anyio in c:\users\agustina\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (4.7.0)
# Requirement already satisfied: certifi in c:\users\agustina\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\agustina\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in c:\users\agustina\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\agustina\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\agustina\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (1.15.3)
# Requirement already satisfied: setuptools<82 in c:\users\agustina\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 5)) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\agustina\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 5)) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\agustina\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 5)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\agustina\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\agustina\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\agustina\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: click in c:\users\agustina\anaconda3\lib\site-packages (from nltk->-r requirements.txt (line 8)) (8.4.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (5.5.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\agustina\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 10)) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from streamlit->-r requirements.txt (line 10)) (6.5.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\agustina\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 10)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\agustina\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 10)) (1.31.0)
# Requirement already satisfied: colorama in c:\users\agustina\appdata\roaming\python\python313\site-packages (from click->nltk->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\agustina\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 10)) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\agustina\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 10)) (4.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agustina\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agustina\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 10)) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 10)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 10)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 10)) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\agustina\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\agustina\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\agustina\anaconda3\lib\site-packages (from typer->transformers->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: rich>=13.8.0 in c:\users\agustina\anaconda3\lib\site-packages (from typer->transformers->-r requirements.txt (line 3)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\agustina\anaconda3\lib\site-packages (from typer->transformers->-r requirements.txt (line 3)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\agustina\anaconda3\lib\site-packages (from rich>=13.8.0->typer->transformers->-r requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from rich>=13.8.0->typer->transformers->-r requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\agustina\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers->-r requirements.txt (line 3)) (0.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\agustina\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (27.0.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: decorator in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: stack_data in c:\users\agustina\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\agustina\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 2)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 2)) (311)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\agustina\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 2)) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in c:\users\agustina\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 2)) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agustina\anaconda3\lib\site-packages (from jinja2->torch->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\agustina\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\agustina\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\agustina\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\agustina\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\agustina\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\agustina\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\agustina\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.9.25)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\agustina\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\agustina\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.1)
# Requirement already satisfied: uri-template in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\agustina\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\agustina\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\agustina\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\agustina\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\agustina\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\agustina\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\agustina\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\agustina\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\agustina\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\agustina\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\agustina\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\agustina\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\agustina\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\agustina\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\agustina\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\agustina\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\agustina\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 2)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\agustina\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\agustina\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\agustina\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\agustina\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\agustina\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\agustina\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\agustina\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Descarga de los recursos de NLTK necesarios (como las stopwords para el procesamiento de texto).

# %%
import nltk

print("Descargando recursos necesarios de NLTK...")
nltk.download('stopwords')
nltk.download('punkt')
print("¡Descarga de recursos completada!")
# Out:
# Descargando recursos necesarios de NLTK...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Agustina\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Agustina\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# ¡Descarga de recursos completada!

# %% [markdown]
# Verificación de que `faiss-cpu` está correctamente importado en el entorno de ejecución.

# %%
try:
    import faiss
    print(f"FAISS importado exitosamente. Versión: {faiss.__version__}")
except ImportError as e:
    print(f"Error al importar FAISS: {e}. Asegúrate de haber instalado 'faiss-cpu'.")
# Out:
# FAISS importado exitosamente. Versión: 1.14.2

# %% [markdown]
# ## 2. Exploración de Datos (EDA)
#
# Carga de los datasets unificados de las distintas plataformas y filtrado de las películas.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

datasets_dir = 'Datasets'
platform_mapping = {
    'amazon_prime_titles.csv': 'Amazon Prime',
    'disney_plus_titles.csv': 'Disney+',
    'hulu_titles.csv': 'Hulu',
    'netflix_titles.csv': 'Netflix'
}

dfs = []
for file, platform_name in platform_mapping.items():
    path = os.path.join(datasets_dir, file)
    if os.path.exists(path):
        df = pd.read_csv(path)
        df['platform'] = platform_name
        dfs.append(df)

all_data = pd.concat(dfs, ignore_index=True)
print(f"Total de registros unificados: {len(all_data)}")

movies = all_data[all_data['type'] == 'Movie'].copy()
print(f"Total de películas: {len(movies)}")
# Out:
# Total de registros unificados: 22998
# Total de películas: 16481

# %% [markdown]
# ### 2.1 Distribución de Películas por Plataforma de Origen

# %%
# Distribución de películas por plataforma
platform_counts = movies['platform'].value_counts()

plt.figure(figsize=(10, 6))
color_map = {
    'Netflix': '#E50914',      
    'Amazon Prime': '#FF9900', 
    'Hulu': '#1C3D5A',         
    'Disney+': '#00A8E1'       
}
palette = [color_map.get(x, '#6C757D') for x in platform_counts.index]

sns.barplot(x=platform_counts.index, y=platform_counts.values, palette=palette)
plt.title('Distribución de Películas por Plataforma de Origen', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Plataforma', fontsize=12)
plt.ylabel('Cantidad de Películas', fontsize=12)

for i, v in enumerate(platform_counts.values):
    plt.text(i, v + 50, f"{v:,}", ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Agustina\AppData\Local\Temp\ipykernel_14552\239544124.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=platform_counts.index, y=platform_counts.values, palette=palette)

# %% [markdown]
# ### 2.2 Cantidad de Lanzamientos de Películas a lo largo de los Años

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=movies, x='release_year', bins=40, kde=True, color='#4A90E2', edgecolor='black', alpha=0.7)
plt.title('Cantidad de Lanzamientos de Películas a lo largo de los Años', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Año de Lanzamiento', fontsize=12)
plt.ylabel('Cantidad de Películas', fontsize=12)
plt.xlim(movies['release_year'].min(), movies['release_year'].max() + 1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3 Frecuencia de los Géneros más Populares

# %%
from collections import Counter

genre_list = movies['listed_in'].dropna().str.split(',')
flat_genres = [genre.strip() for sublist in genre_list for genre in sublist if genre.strip()]
genre_counts = Counter(flat_genres).most_common(15)

df_genres = pd.DataFrame(genre_counts, columns=['Género', 'Frecuencia'])

plt.figure(figsize=(12, 7))
sns.barplot(data=df_genres, y='Género', x='Frecuencia', palette='viridis')
plt.title('Top 15 Géneros más Populares en el Catálogo de Películas', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Frecuencia', fontsize=12)
plt.ylabel('Género', fontsize=12)

for i, v in enumerate(df_genres['Frecuencia']):
    plt.text(v + 30, i, f"{v:,}", ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Agustina\AppData\Local\Temp\ipykernel_14552\1513140211.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_genres, y='Género', x='Frecuencia', palette='viridis')

# %% [markdown]
# ### 2.4 Análisis de Longitud de Textos (Cantidad de palabras en las sinopsis)

# %%
movies['word_count'] = movies['description'].fillna('').apply(lambda x: len(x.split()))

plt.figure(figsize=(12, 6))
sns.histplot(data=movies, x='word_count', bins=30, kde=True, color='#8E44AD', edgecolor='black', alpha=0.7)
plt.title('Distribución de la Cantidad de Palabras en las Sinopsis', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Cantidad de Palabras', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

mean_len = movies['word_count'].mean()
median_len = movies['word_count'].median()
plt.axvline(mean_len, color='red', linestyle='--', linewidth=1.5, label=f'Media: {mean_len:.1f}')
plt.axvline(median_len, color='green', linestyle='-', linewidth=1.5, label=f'Mediana: {median_len:.1f}')

plt.legend(fontsize=11)
plt.tight_layout()
plt.show()
